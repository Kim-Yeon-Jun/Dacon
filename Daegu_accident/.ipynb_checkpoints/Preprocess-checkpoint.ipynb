# %%
import pandas as pd

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
target_col = ['사망자수','중상자수','경상자수','부상자수']

# %%
use_col = df_test.columns.tolist()
use_col.extend(target_col)

# %%
df_train = df_train[use_col]

# %%
df_train.head()
# Out:
#                ID           사고일시   요일 기상상태            시군구      도로형태 노면상태  \
# 0  ACCIDENT_00000  2019-01-01 00  화요일   맑음   대구광역시 중구 대신동  단일로 - 기타   건조
# 1  ACCIDENT_00001  2019-01-01 00  화요일   흐림  대구광역시 달서구 감삼동  단일로 - 기타   건조
# 2  ACCIDENT_00002  2019-01-01 01  화요일   맑음  대구광역시 수성구 두산동  단일로 - 기타   건조
# 3  ACCIDENT_00003  2019-01-01 02  화요일   맑음   대구광역시 북구 복현동  단일로 - 기타   건조
# 4  ACCIDENT_00004  2019-01-01 04  화요일   맑음   대구광역시 동구 신암동  단일로 - 기타   건조
#
#    사고유형  사망자수  중상자수  경상자수  부상자수
# 0  차대사람     0     1     0     0
# 1  차대사람     0     0     1     0
# 2  차대사람     0     0     1     0
# 3   차대차     0     1     0     0
# 4   차대차     0     0     1     0

# %%
df_test.head()
# Out:
#                ID           사고일시   요일 기상상태              시군구        도로형태 노면상태  \
# 0  ACCIDENT_39609  2022-01-01 01  토요일   맑음     대구광역시 수성구 상동  교차로 - 교차로안   건조
# 1  ACCIDENT_39610  2022-01-01 01  토요일   맑음    대구광역시 수성구 지산동    단일로 - 기타   건조
# 2  ACCIDENT_39611  2022-01-01 04  토요일   맑음  대구광역시 수성구 수성동2가  교차로 - 교차로안   건조
# 3  ACCIDENT_39612  2022-01-01 04  토요일   맑음    대구광역시 수성구 신매동    단일로 - 기타   건조
# 4  ACCIDENT_39613  2022-01-01 06  토요일   맑음    대구광역시 달서구 감삼동  교차로 - 교차로안   건조
#
#    사고유형
# 0  차대사람
# 1  차대사람
# 2   차대차
# 3   차대차
# 4   차대차

# %%
df_train.drop(['ID'], axis = 1,inplace = True)
df_test.drop(['ID'], axis = 1,inplace = True)

# %%
df_train.drop(['사고일시'], axis = 1,inplace = True)
df_test.drop(['사고일시'], axis = 1,inplace = True)

# %%
day_map = {
    '월요일' : '평일',
    '화요일' : '평일',
    '수요일' : '평일',
    '목요일' : '평일',
    '금요일' : '평일',
    '토요일' : '주말',
    '일요일' : '주말'
}

# %%
df_train['요일'] = df_train['요일'].replace(day_map)

df_test['요일'] = df_test['요일'].replace(day_map)

# %%
df_train = pd.concat([df_train, pd.get_dummies(df_train['요일'])], axis=1)

df_test = pd.concat([df_test, pd.get_dummies(df_train['요일'])], axis=1)

# %%
df_train.drop(['요일'], axis = 1,inplace = True)
df_test.drop(['요일'], axis = 1,inplace = True)

# %%
df_train.head()
# Out:
#   기상상태            시군구      도로형태 노면상태  사고유형  사망자수  중상자수  경상자수  부상자수     주말  \
# 0   맑음   대구광역시 중구 대신동  단일로 - 기타   건조  차대사람     0     1     0     0  False
# 1   흐림  대구광역시 달서구 감삼동  단일로 - 기타   건조  차대사람     0     0     1     0  False
# 2   맑음  대구광역시 수성구 두산동  단일로 - 기타   건조  차대사람     0     0     1     0  False
# 3   맑음   대구광역시 북구 복현동  단일로 - 기타   건조   차대차     0     1     0     0  False
# 4   맑음   대구광역시 동구 신암동  단일로 - 기타   건조   차대차     0     0     1     0  False
#
#      평일
# 0  True
# 1  True
# 2  True
# 3  True
# 4  True

# %%
df_test.head()
# Out:
#   기상상태              시군구        도로형태 노면상태  사고유형     주말    평일
# 0   맑음     대구광역시 수성구 상동  교차로 - 교차로안   건조  차대사람  False  True
# 1   맑음    대구광역시 수성구 지산동    단일로 - 기타   건조  차대사람  False  True
# 2   맑음  대구광역시 수성구 수성동2가  교차로 - 교차로안   건조   차대차  False  True
# 3   맑음    대구광역시 수성구 신매동    단일로 - 기타   건조   차대차  False  True
# 4   맑음    대구광역시 달서구 감삼동  교차로 - 교차로안   건조   차대차  False  True

# %%
df_train['기상상태'].value_counts()
# Out:
# 기상상태
# 맑음    36181
# 비      2627
# 흐림      729
# 기타       56
# 안개        8
# 눈         8
# Name: count, dtype: int64

# %%
df_test['기상상태'].value_counts()
# Out:
# 기상상태
# 맑음    10321
# 비       394
# 흐림      207
# 기타       31
# 눈        10
# Name: count, dtype: int64

# %%
df_train.drop(df_train[df_train['기상상태'] == '안개'].index, axis = 0, inplace = True)

df_train.reset_index(drop=True, inplace = True)

# %%
df_train['기상상태'].value_counts()
# Out:
# 기상상태
# 맑음    36181
# 비      2627
# 흐림      729
# 기타       56
# 눈         8
# Name: count, dtype: int64

# %%
df_train = pd.concat([df_train, pd.get_dummies(df_train['기상상태'])], axis=1)

df_test = pd.concat([df_test, pd.get_dummies(df_test['기상상태'])], axis=1)

df_train.drop(['기상상태'], axis=1, inplace = True)
df_test.drop(['기상상태'], axis=1, inplace = True)

# %%
df_train.head()
# Out:
#              시군구      도로형태 노면상태  사고유형  사망자수  중상자수  경상자수  부상자수     주말    평일  \
# 0   대구광역시 중구 대신동  단일로 - 기타   건조  차대사람     0     1     0     0  False  True
# 1  대구광역시 달서구 감삼동  단일로 - 기타   건조  차대사람     0     0     1     0  False  True
# 2  대구광역시 수성구 두산동  단일로 - 기타   건조  차대사람     0     0     1     0  False  True
# 3   대구광역시 북구 복현동  단일로 - 기타   건조   차대차     0     1     0     0  False  True
# 4   대구광역시 동구 신암동  단일로 - 기타   건조   차대차     0     0     1     0  False  True
#
#       기타      눈     맑음      비     흐림
# 0  False  False   True  False  False
# 1  False  False  False  False   True
# 2  False  False   True  False  False
# 3  False  False   True  False  False
# 4  False  False   True  False  False

# %%
df_test.head()
# Out:
#                시군구        도로형태 노면상태  사고유형     주말    평일     기타      눈    맑음  \
# 0     대구광역시 수성구 상동  교차로 - 교차로안   건조  차대사람  False  True  False  False  True
# 1    대구광역시 수성구 지산동    단일로 - 기타   건조  차대사람  False  True  False  False  True
# 2  대구광역시 수성구 수성동2가  교차로 - 교차로안   건조   차대차  False  True  False  False  True
# 3    대구광역시 수성구 신매동    단일로 - 기타   건조   차대차  False  True  False  False  True
# 4    대구광역시 달서구 감삼동  교차로 - 교차로안   건조   차대차  False  True  False  False  True
#
#        비     흐림
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False

# %%
df_train['구'] = ''

for i in range(len(df_train)):
    df_train.iloc[i, 15] = df_train.iloc[i, 0].split()[1]

df_train.drop(['시군구'], axis=1, inplace = True)

# %%
df_train = pd.concat([df_train, pd.get_dummies(df_train['구'])], axis=1)

df_test = pd.concat([df_test, pd.get_dummies(df_test['구'])], axis=1)

# %%
df_train.head()
# Out:
#        도로형태 노면상태  사고유형  사망자수  중상자수  경상자수  부상자수     주말    평일     기타  ...  \
# 0  단일로 - 기타   건조  차대사람     0     1     0     0  False  True  False  ...
# 1  단일로 - 기타   건조  차대사람     0     0     1     0  False  True  False  ...
# 2  단일로 - 기타   건조  차대사람     0     0     1     0  False  True  False  ...
# 3  단일로 - 기타   건조   차대차     0     1     0     0  False  True  False  ...
# 4  단일로 - 기타   건조   차대차     0     0     1     0  False  True  False  ...
#
#       흐림    구     남구    달서구    달성군     동구     북구     서구    수성구     중구
# 0  False   중구  False  False  False  False  False  False  False   True
# 1   True  달서구  False   True  False  False  False  False  False  False
# 2  False  수성구  False  False  False  False  False  False   True  False
# 3  False   북구  False  False  False  False   True  False  False  False
# 4  False   동구  False  False  False   True  False  False  False  False
#
# [5 rows x 23 columns]

# %%
df_test.head()
# Out:
#                시군구        도로형태 노면상태  사고유형     주말    평일     기타      눈    맑음  \
# 0     대구광역시 수성구 상동  교차로 - 교차로안   건조  차대사람  False  True  False  False  True
# 1    대구광역시 수성구 지산동    단일로 - 기타   건조  차대사람  False  True  False  False  True
# 2  대구광역시 수성구 수성동2가  교차로 - 교차로안   건조   차대차  False  True  False  False  True
# 3    대구광역시 수성구 신매동    단일로 - 기타   건조   차대차  False  True  False  False  True
# 4    대구광역시 달서구 감삼동  교차로 - 교차로안   건조   차대차  False  True  False  False  True
#
#        비  ...    구            남구    달서구    달성군     동구     북구     서구    수성구  \
# 0  False  ...  수성구  False  False  False  False  False  False  False   True
# 1  False  ...  수성구  False  False  False  False  False  False  False   True
# 2  False  ...  수성구  False  False  False  False  False  False  False   True
# 3  False  ...  수성구  False  False  False  False  False  False  False   True
# 4  False  ...  달서구  False  False   True  False  False  False  False  False
#
#       중구
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
# [5 rows x 21 columns]

# %%
df_train['도로형태'].value_counts()
# Out:
# 도로형태
# 단일로 - 기타           19481
# 교차로 - 교차로안          9928
# 교차로 - 교차로부근         5746
# 기타 - 기타             1986
# 교차로 - 교차로횡단보도내      1474
# 단일로 - 지하차도(도로)내      309
# 주차장 - 주차장            236
# 단일로 - 교량             231
# 단일로 - 고가도로위          138
# 단일로 - 터널              64
# 미분류 - 미분류              8
# Name: count, dtype: int64

# %%
df_test['도로형태'].value_counts()
# Out:
# 도로형태
# 단일로 - 기타           5039
# 교차로 - 교차로안         2540
# 교차로 - 교차로부근        1673
# 기타 - 기타             752
# 교차로 - 교차로횡단보도내      480
# 단일로 - 지하차도(도로)내     273
# 단일로 - 교량             74
# 주차장 - 주차장            64
# 단일로 - 고가도로위          52
# 단일로 - 터널             15
# 미분류 - 미분류             1
# Name: count, dtype: int64

# %%
df_train = pd.concat([df_train, pd.get_dummies(df_train['도로형태'])], axis=1)
df_test = pd.concat([df_test, pd.get_dummies(df_test['도로형태'])], axis=1)

df_train.drop(['도로형태'], axis=1, inplace = True)
df_test.drop(['도로형태'], axis=1, inplace = True)

# %%
df_train['노면상태'].value_counts()
# Out:
# 노면상태
# 건조       36420
# 젖음/습기     3095
# 기타          56
# 서리/결빙       24
# 침수           3
# 적설           3
# Name: count, dtype: int64

# %%
df_test['노면상태'].value_counts()
# Out:
# 노면상태
# 건조       10394
# 젖음/습기      524
# 기타          35
# 서리/결빙        7
# 침수           2
# 적설           1
# Name: count, dtype: int64

# %%
df_train = pd.concat([df_train, pd.get_dummies(df_train['노면상태'])], axis=1)
df_test = pd.concat([df_test, pd.get_dummies(df_test['노면상태'])], axis=1)

df_train.drop(['노면상태'], axis=1, inplace = True)
df_test.drop(['노면상태'], axis=1, inplace = True)

# %%
df_train['사고유형'].value_counts()
# Out:
# 사고유형
# 차대차     31777
# 차대사람     6833
# 차량단독      991
# Name: count, dtype: int64

# %%
df_test['사고유형'].value_counts()
# Out:
# 사고유형
# 차대차     8559
# 차대사람    2079
# 차량단독     325
# Name: count, dtype: int64

# %%
df_train = pd.concat([df_train, pd.get_dummies(df_train['사고유형'])], axis=1)
df_test = pd.concat([df_test, pd.get_dummies(df_test['사고유형'])], axis=1)

df_train.drop(['사고유형'], axis=1, inplace = True)
df_test.drop(['사고유형'], axis=1, inplace = True)

# %%
df_train.head()
# Out:
#    사망자수  중상자수  경상자수  부상자수     주말    평일     기타      눈     맑음      비  ...  \
# 0     0     1     0     0  False  True  False  False   True  False  ...
# 1     0     0     1     0  False  True  False  False  False  False  ...
# 2     0     0     1     0  False  True  False  False   True  False  ...
# 3     0     1     0     0  False  True  False  False   True  False  ...
# 4     0     0     1     0  False  True  False  False   True  False  ...
#
#    주차장 - 주차장    건조     기타  서리/결빙     적설  젖음/습기     침수   차대사람    차대차   차량단독
# 0      False  True  False  False  False  False  False   True  False  False
# 1      False  True  False  False  False  False  False   True  False  False
# 2      False  True  False  False  False  False  False   True  False  False
# 3      False  True  False  False  False  False  False  False   True  False
# 4      False  True  False  False  False  False  False  False   True  False
#
# [5 rows x 40 columns]

# %%
df_train.dropna()
df_test.dropna()
# Out:
#                    시군구     주말    평일     기타      눈    맑음      비     흐림    구  \
# 0         대구광역시 수성구 상동  False  True  False  False  True  False  False  수성구
# 1        대구광역시 수성구 지산동  False  True  False  False  True  False  False  수성구
# 2      대구광역시 수성구 수성동2가  False  True  False  False  True  False  False  수성구
# 3        대구광역시 수성구 신매동  False  True  False  False  True  False  False  수성구
# 4        대구광역시 달서구 감삼동  False  True  False  False  True  False  False  달서구
# ...                ...    ...   ...    ...    ...   ...    ...    ...  ...
# 10958     대구광역시 남구 대명동  False  True  False  False  True  False  False   남구
# 10959    대구광역시 수성구 시지동  False  True  False  False  True  False  False  수성구
# 10960    대구광역시 수성구 연호동  False  True  False  False  True  False  False  수성구
# 10961    대구광역시 수성구 범물동  False  True  False  False  True  False  False  수성구
# 10962     대구광역시 동구 효목동  False  True  False  False  True  False  False   동구
#
#               ...  주차장 - 주차장    건조     기타  서리/결빙     적설  젖음/습기     침수   차대사람  \
# 0      False  ...      False  True  False  False  False  False  False   True
# 1      False  ...      False  True  False  False  False  False  False   True
# 2      False  ...      False  True  False  False  False  False  False  False
# 3      False  ...      False  True  False  False  False  False  False  False
# 4      False  ...      False  True  False  False  False  False  False  False
# ...      ...  ...        ...   ...    ...    ...    ...    ...    ...    ...
# 10958  False  ...      False  True  False  False  False  False  False  False
# 10959  False  ...      False  True  False  False  False  False  False  False
# 10960  False  ...      False  True  False  False  False  False  False  False
# 10961  False  ...      False  True  False  False  False  False  False  False
# 10962  False  ...      False  True  False  False  False  False  False  False
#
#          차대차   차량단독
# 0      False  False
# 1      False  False
# 2       True  False
# 3       True  False
# 4       True  False
# ...      ...    ...
# 10958   True  False
# 10959   True  False
# 10960   True  False
# 10961   True  False
# 10962   True  False
#
# [10963 rows x 38 columns]

# %%
# df_train.to_csv("df_train.csv", encoding='utf-8')
# df_test.to_csv("df_test.csv", encoding='utf-8')
